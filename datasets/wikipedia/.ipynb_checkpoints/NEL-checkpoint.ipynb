# %%
### Named Entity Linking to identify characteristics from arbitrary piece of text.
### Using Flair Library for NER Paper: https://www.aclweb.org/anthology/N19-4010.pdf

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

from tqdm.notebook import tqdm
import numpy as np
import pandas as pd

### load NER tagger model
tagger = SequenceTagger.load('ner')
# Out:
# 2021-04-11 22:01:50,205 --------------------------------------------------------------------------------
# 2021-04-11 22:01:50,205 The model key 'ner' now maps to 'https://huggingface.co/flair/ner-english' on the HuggingFace ModelHub
# 2021-04-11 22:01:50,206  - The most current version of the model is automatically downloaded from there.
# 2021-04-11 22:01:50,206  - (you can alternatively manually download the original model at https://nlp.informatik.hu-berlin.de/resources/models/ner/en-ner-conll03-v0.4.pt)
# 2021-04-11 22:01:50,207 --------------------------------------------------------------------------------
# 2021-04-11 22:01:50,391 loading file /Users/qasimwani/.flair/models/ner-english/4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4

# %%
df = pd.read_csv('law_data.csv')
del df['Unnamed: 0'] #remove first index

# %%
df.head()
# Out:
#                       Header    State  Year  \
# 0  Ala. Code 37-16-1 et seq.  Alabama  2019
# 1          Ala. Code 37-16-2  Alabama  2019
# 2          Ala. Code 37-16-3  Alabama  2019
# 3          Ala. Code 37-16-3  Alabama  2019
# 4          Ala. Code 37-16-7  Alabama  2019
#
#                                                Title  \
# 0  Broadband Using Electric Easements Accessibili...
# 1  Broadband Using Electric Easements Accessibili...
# 2  Broadband Using Electric Easements Accessibili...
# 3  Broadband Using Electric Easements Accessibili...
# 4  Broadband Using Electric Easements Accessibili...
#
#                                Category  \
# 0  Category: Competition and regulation
# 1                       Category: Other
# 2                 Category: Definitions
# 3                 Category: Definitions
# 4       Category: Infrastructure access
#
#                                                Topic  \
# 0                                Topic: Cooperatives
# 1                          Topic: Legislative intent
# 2  Topic: Definition - Broadband (As defined by F...
# 3        Topic: Definition - Broadband (Other speed)
# 4                    Topic: Right of way (Easements)
#
#                                              Summary  \
# 0  Allows electric utilities to also provide broa...
# 1  Declares that the state intends to encourage t...
# 2  Defines "advanced communications capabilities"...
# 3  Defines broadband as an internet connection th...
# 4  Specifies the terms under which a property own...
#
#                                            StateCode
# 0  (a) To the extent not otherwise authorized by ...
# 1  (a) The Legislature finds and declares the fol...
# 2  (l) Advanced Communications Capabilities. The ...
# 3  (5) Broadband Services. The provision of conne...
# 4  (a) If the owner of an interest in real proper...

# %%
summaries = np.array(df.Summary) #gather all summaries

# %%
def generate_entities(text):
    """
    Generate NER for a given piece of text
    Return: 
    - Token, Label. Shape: ~O(n x 2), where n is number of elements in text.
    """
    # make a sentence
    sentence = Sentence(text)
    # run NER over sentence
    tagger.predict(sentence)
    # iterate over entities
    tokens = []; labels = []
    for entity in sentence.get_spans('ner'):
        tokens.append(entity.to_plain_string())
        labels += [label.value for label in entity.labels]
    return tokens, labels

# %%
tokens = []; labels = []

#generate NER report
for summary in tqdm(summaries):
    tk, lb = generate_entities(summary)
    tokens.append(", ".join(tk) or None)
    labels.append(", ".join(lb) or None)
# Out:
#   0%|          | 0/851 [00:00<?, ?it/s]
# [] []
# [] []
# ['ORG']
# ['FCC'] ['ORG']
# [] []
# [] []
# ['ORG']
# ['Legislature'] ['ORG']
# ['ORG']
# ['Universal Service Fund'] ['ORG']
# [] []
# ['ORG']
# ['ORG', 'ORG']
# ['ORG', 'ORG', 'ORG']
# ['ORG', 'ORG', 'ORG', 'ORG']
# ['Alabama Broadband Accessibility Fund', 'Treasury', 'Alabama Department of Economic and Community Affairs', 'Legislature'] ['ORG', 'ORG', 'ORG', 'ORG']
# ['ORG']
# ['Alabama Rural Broadband Oversight Committee'] ['ORG']
# ['ORG']
# ['Alabama Department of Economic and Community Affairs'] ['ORG']
# [] []
# ['ORG']
# ['Alabama AHEAD'] ['ORG']
# ['ORG']
# ['Public Service Commission'] ['ORG']
# [] []
# [] []
# [] []
# [] []
# [] []
# ['ORG']
# ['Education Trust Fund Advancement and Technology Fund'] ['ORG']
# ['ORG']
# ['ORG', 'ORG']
# ['Legislature', 'Department of Commerce, Community, and Economic Development'] ['ORG', 'ORG']
# ['ORG']
# ['ORG', 'ORG']
# ['ORG', 'ORG', 'LOC']
# ['Legislature', 'Regulatory Commission', 'Alaska'] ['ORG', 'ORG', 'LOC']
# [] []
# ['ORG']
# ['Regulatory Commission of Alaska'] ['ORG']
# ['ORG']
# ['ORG', 'ORG']
# ['Arizona Commerce Authority', 'Legislature'] ['ORG', 'ORG']
# [] []
# [] []
# ['ORG']
# ['Department of Education'] ['ORG']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-c82e672a7eda> in <module>
#       3 #generate NER report
#       4 for summary in tqdm(summaries):
# ----> 5     tk, lb = generate_entities(summary)
#       6     print(tk, lb)
#       7     tokens.append(", ".join(tk) or None)
#
# <ipython-input-49-9f73d82d157b> in generate_entities(text)
#       8     sentence = Sentence(text)
#       9     # run NER over sentence
# ---> 10     tagger.predict(sentence)
#      11     # iterate over entities
#      12     tokens = []; labels = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/models/sequence_tagger_model.py in predict(self, sentences, mini_batch_size, all_tag_prob, verbose, label_name, return_loss, embedding_storage_mode)
#     377                     continue
#     378
# --> 379                 feature = self.forward(batch)
#     380
#     381                 if return_loss:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/models/sequence_tagger_model.py in forward(self, sentences)
#     640     def forward(self, sentences: List[Sentence]):
#     641
# --> 642         self.embeddings.embed(sentences)
#     643
#     644         names = self.embeddings.get_names()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/embeddings/token.py in embed(self, sentences, static_embeddings)
#      79
#      80         for embedding in self.embeddings:
# ---> 81             embedding.embed(sentences)
#      82
#      83     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/embeddings/base.py in embed(self, sentences)
#      58
#      59         if not everything_embedded or not self.static_embeddings:
# ---> 60             self._add_embeddings_internal(sentences)
#      61
#      62         return sentences
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/embeddings/token.py in _add_embeddings_internal(self, sentences)
#     623             # get hidden states from language model
#     624             all_hidden_states_in_lm = self.lm.get_representation(
# --> 625                 text_sentences, start_marker, end_marker, self.chars_per_chunk
#     626             )
#     627
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/models/language_model.py in get_representation(self, strings, start_marker, end_marker, chars_per_chunk)
#     155         for batch in batches:
#     156             batch = batch.transpose(0, 1)
# --> 157             _, rnn_output, hidden = self.forward(batch, hidden)
#     158             output_parts.append(rnn_output)
#     159
#
# ~/opt/anaconda3/lib/python3.7/site-packages/flair/models/language_model.py in forward(self, input, hidden, ordered_sequence_lengths)
#      78         self.rnn.flatten_parameters()
#      79
# ---> 80         output, hidden = self.rnn(emb, hidden)
#      81
#      82         if self.proj is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     580         if batch_sizes is None:
#     581             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 582                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     583         else:
#     584             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
df['NER_tokens'] = tokens
df['NER_labels'] = labels

# %%
df.head()
# Out:
#                       Header    State  Year  \
# 0  Ala. Code 37-16-1 et seq.  Alabama  2019
# 1          Ala. Code 37-16-2  Alabama  2019
# 2          Ala. Code 37-16-3  Alabama  2019
# 3          Ala. Code 37-16-3  Alabama  2019
# 4          Ala. Code 37-16-7  Alabama  2019
#
#                                                Title  \
# 0  Broadband Using Electric Easements Accessibili...
# 1  Broadband Using Electric Easements Accessibili...
# 2  Broadband Using Electric Easements Accessibili...
# 3  Broadband Using Electric Easements Accessibili...
# 4  Broadband Using Electric Easements Accessibili...
#
#                                Category  \
# 0  Category: Competition and regulation
# 1                       Category: Other
# 2                 Category: Definitions
# 3                 Category: Definitions
# 4       Category: Infrastructure access
#
#                                                Topic  \
# 0                                Topic: Cooperatives
# 1                          Topic: Legislative intent
# 2  Topic: Definition - Broadband (As defined by F...
# 3        Topic: Definition - Broadband (Other speed)
# 4                    Topic: Right of way (Easements)
#
#                                              Summary  \
# 0  Allows electric utilities to also provide broa...
# 1  Declares that the state intends to encourage t...
# 2  Defines "advanced communications capabilities"...
# 3  Defines broadband as an internet connection th...
# 4  Specifies the terms under which a property own...
#
#                                            StateCode  \
# 0  (a) To the extent not otherwise authorized by ...
# 1  (a) The Legislature finds and declares the fol...
# 2  (l) Advanced Communications Capabilities. The ...
# 3  (5) Broadband Services. The provision of conne...
# 4  (a) If the owner of an interest in real proper...
#
#                                           NER_tokens NER_labels
# 0                                               None       None
# 1                                               None       None
# 2  F, ,,  , ,, ,,  ,  , ,,  , C, ,,  , ,, ,,  ,  ...        ORG
# 3                                               None       None
# 4                                               None       None

# %%
df.to_csv('updated_law_text.csv', index=False) #save file
