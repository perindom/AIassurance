# %% [markdown]
# ### About:
# 4/11/2021 Program calculate the correlation coefficient: => TBD
#
#     (1) between internet speeds
#     (2) between states
#     (3) between states & internet speeds??? -> Self Assigned
#
# #### NOTE: Make sure to unzip the xlsx files
#
# @author: Minh Nguyen @AIA
#
# @credit: Qasim, Andrei @AIA

# %%
import numpy as np
from numpy.random import randn
from numpy.random import seed
from numpy import array_split
import pandas as pd
from sklearn import metrics as mt
from sklearn import model_selection as md
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn.datasets as ds
import random

# %% [markdown]
# ### Correlation Calculation

# %%
def correlation_cal(df):
    # Instead of just dropping the missing values, we will fill in N/A values
    if df.isna().values.any():
        while True:
            missing_type = input("Please enter the type of missing value replacement: mean, medium, mode, or drop from the row")
            missing_type = missing_type.lower()
            if(missing_type in ['mean', 'median', 'mode', 'drop']):
                if(missing_type == 'mean'):
                    df.fillna(df.mean(), inplace=True)
                elif(missing_type == 'median'):
                    df.fillna(df.median(), inplace=True)
                elif(missing_type == 'mode'):
                    df.fillna(df.mode(), inplace=True)
                else:
                    df.dropna()
                break
            else:
                print("Please input the option from the list")
    
    # Calculate input data correlation
    while True:
        corr_type = input("Please enter type of correlation: Pearson, Spearman, or Kendall: ")
        corr_type = corr_type.lower()
        if corr_type in ['pearson', 'spearman', 'kendall']:
            break
        else:
            print("Please try again")
    
    # Plot correlation matrix
    corrMatrix = df.corr(method=corr_type)
    _, ax = plt.subplots(figsize=(12, 10))
    sns.heatmap(corrMatrix, ax = ax, cmap="gray", linewidths = 0.1) # cmap can also be "YlGnBu"

# %% [markdown]
# #### Preprocess Data

# %%
# !ls
# Out:
# Correlation - Fixed BB 4.ipynb
# fixed_bb_2018.csv

# %%
def parse_data(file):
    """ Function load csv file into csd pandas """
    dataset = pd.read_csv(file)
    return dataset

# %%
df = parse_data("fixed_bb_2018.csv")

# %%
df
# Out:
#      Unnamed: 0  logrecno  provider_id       frn  \
# 0             0  46429531        55262  18756155
# 1             1   4535616        55394   4372322
# 2             2   4448974        55394   4372322
# 3             3   2211991        54692   6115901
# 4             4  48694132        59349   1568880
# ..          ...       ...          ...       ...
# 995         995  38343519        67056   1857952
# 996         996  36279471        67052   2860856
# 997         997  46779983        59349   1568880
# 998         998  23411564        57383  13778857
# 999         999  55246934        55262  18756155
#
#                                           providername  \
# 0                                    VSAT Systems, LLC
# 1                   UNITED STATES CELLULAR CORPORATION
# 2                   UNITED STATES CELLULAR CORPORATION
# 3    ERIE COUNTY CABLEVISION INC  DBA =  THE CABLES...
# 4                              GCI Communication Corp.
# ..                                                 ...
# 995                 BellSouth Telecommunications, Inc.
# 996                    Illinois Bell Telephone Company
# 997                            GCI Communication Corp.
# 998            Liberty Cablevision of Puerto Rico, LLC
# 999                                  VSAT Systems, LLC
#
#                                 dbaname                holdingcompanyname  \
# 0                            Skycasters                 VSAT Systems, LLC
# 1    United States Cellular Corporation  Telephone and Data Systems, Inc.
# 2    United States Cellular Corporation  Telephone and Data Systems, Inc.
# 3                   Buckeye Cablesystem        Block Communications, Inc.
# 4               GCI Communication Corp.                  GCI Holdings LLC
# ..                                  ...                               ...
# 995                    AT&T Mississippi                         AT&T Inc.
# 996                       AT&T Illinois                         AT&T Inc.
# 997             GCI Communication Corp.                  GCI Holdings LLC
# 998                             Liberty             Liberty Latin America
# 999                          Skycasters                 VSAT Systems, LLC
#
#      hoconum                         hocofinal stateabbr        blockcode  \
# 0     300167                 VSAT Systems, LLC        DE  100050505043007
# 1     131310  Telephone and Data Systems, Inc.        CA   60230012002165
# 2     131310  Telephone and Data Systems, Inc.        WI  550791853003001
# 3     130137        Block Communications, Inc.        OH  390430414002059
# 4     130534                  GCI Holdings LLC        ID  160139602002047
# ..       ...                               ...       ...              ...
# 995   130077                         AT&T Inc.        MS  280519501002050
# 996   130077                         AT&T Inc.        IL  171118708092065
# 997   130534                  GCI Holdings LLC        FL  120990078352009
# 998   130741             Liberty Latin America        PR  720133011002007
# 999   300167                 VSAT Systems, LLC        MI  260639507001026
#
#      techcode  consumer  maxaddown  maxadup  business
# 0          60         1        2.0    1.300         1
# 1          70         1        2.0    0.064         0
# 2          70         1        2.0    0.064         0
# 3          42         1      300.0   10.000         1
# 4          60         0        0.0    0.000         1
# ..        ...       ...        ...      ...       ...
# 995        11         1       12.0    0.512         0
# 996        10         1        6.0    0.512         0
# 997        60         0        0.0    0.000         1
# 998        42         1      400.0   30.000         1
# 999        60         1        2.0    1.300         1
#
# [1000 rows x 16 columns]
