# %% [markdown]
# ### About:
# 4/11/2021 Program calculate the correlation coefficient: => TBD
#
#     (1) between internet speeds
#     (2) between states
#     (3) between states & internet speeds??? -> Self Assigned
#
# #### NOTE: Make sure to unzip the xlsx files
#
# @author: Minh Nguyen @AIA
#
# @credit: Qasim, Andrei @AIA

# %%
import numpy as np
from numpy.random import randn
from numpy.random import seed
from numpy import array_split
import pandas as pd
from sklearn import metrics as mt
from sklearn import model_selection as md
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn.datasets as ds
import random

# %% [markdown]
# ### Correlation Calculation

# %%
def correlation_cal(df):
    # Instead of just dropping the missing values, we will fill in N/A values
    if df.isna().values.any():
        while True:
            missing_type = input("Please enter the type of missing value replacement: mean, medium, mode, or drop from the row")
            missing_type = missing_type.lower()
            if(missing_type in ['mean', 'median', 'mode', 'drop']):
                if(missing_type == 'mean'):
                    df.fillna(df.mean(), inplace=True)
                elif(missing_type == 'median'):
                    df.fillna(df.median(), inplace=True)
                elif(missing_type == 'mode'):
                    df.fillna(df.mode(), inplace=True)
                else:
                    df.dropna()
                break
            else:
                print("Please input the option from the list")
    
    # Calculate input data correlation
    while True:
        corr_type = input("Please enter type of correlation: Pearson, Spearman, or Kendall: ")
        corr_type = corr_type.lower()
        if corr_type in ['pearson', 'spearman', 'kendall']:
            break
        else:
            print("Please try again")
    
    # Plot correlation matrix
    corrMatrix = df.corr(method=corr_type)
    _, ax = plt.subplots(figsize=(12, 10))
    sns.heatmap(corrMatrix, ax = ax, cmap="gray", linewidths = 0.1) # cmap can also be "YlGnBu"

# %% [markdown]
# #### Preprocess Data

# %%
# !ls
# Out:
# Correlation - Fixed BB 5.ipynb
# fixed_bb_2019.csv

# %%
def parse_data(file):
    """ Function load csv file into csd pandas """
    dataset = pd.read_csv(file)
    return dataset

# %%
df = parse_data("fixed_bb_2019.csv")

# %%
df
# Out:
#      Unnamed: 0  logrecno  provider_id       frn  \
# 0             0   2644844        54875   1786706
# 1             1  20929408        56631   6221287
# 2             2  53250210        54694  12369286
# 3             3  23447017        57383  13778857
# 4             4  26732513        58623  25646373
# ..          ...       ...          ...       ...
# 995         995  43770688        59349   1568880
# 996         996  17092713        56004   4963088
# 997         997  12324925        56004   4963088
# 998         998  72743259        55262  18756155
# 999         999  17604059        56004   4963088
#
#                                      providername                     dbaname  \
# 0    Kentucky RSA #3 Cellular General Partnership      Bluegrass Cellular Inc
# 1                      Harbor Communications, LLC       Harbor Communications
# 2                            HNS License Sub, LLC                   HughesNet
# 3         Liberty Cablevision of Puerto Rico, LLC                     Liberty
# 4                    Charter Communications, Inc.  Charter Communications Inc
# ..                                            ...                         ...
# 995                       GCI Communication Corp.     GCI Communication Corp.
# 996                                  ViaSat, Inc.                  Viasat Inc
# 997                                  ViaSat, Inc.                  Viasat Inc
# 998                             VSAT Systems, LLC                  Skycasters
# 999                                  ViaSat, Inc.                  Viasat Inc
#
#                    holdingcompanyname  hoconum  \
# 0    Brandenburg Cellular Corporation   130146
# 1               Harbor Communications   130587
# 2         Hughes Network Systems, LLC   130627
# 3               Liberty Latin America   130741
# 4              Charter Communications   130235
# ..                                ...      ...
# 995                  GCI Holdings LLC   130534
# 996                      ViaSat, Inc.   290111
# 997                      ViaSat, Inc.   290111
# 998                 VSAT Systems, LLC   300167
# 999                      ViaSat, Inc.   290111
#
#                             hocofinal stateabbr        blockcode  techcode  \
# 0    Brandenburg Cellular Corporation        KY  212139703004003        70
# 1               Harbor Communications        LA  220510205151012        70
# 2         Hughes Network Systems, LLC        LA  220730105022032        60
# 3               Liberty Latin America        PR  720572702013075        42
# 4              Charter Communications        TX  484391006022048        43
# ..                                ...       ...              ...       ...
# 995                  GCI Holdings LLC        CA   60379011023032        60
# 996                      ViaSat, Inc.        SC  450559705002023        60
# 997                      ViaSat, Inc.        KY  210539701002067        60
# 998                 VSAT Systems, LLC        WI  551010020022007        60
# 999                      ViaSat, Inc.        TX  480610102031058        60
#
#      consumer  maxaddown  maxadup  business
# 0           1       12.0      5.0         1
# 1           1       20.0     20.0         1
# 2           1       25.0      3.0         1
# 3           1      400.0     30.0         1
# 4           1      940.0     35.0         1
# ..        ...        ...      ...       ...
# 995         0        0.0      0.0         1
# 996         1      100.0      3.0         1
# 997         1       35.0      3.0         1
# 998         1        2.0      1.3         1
# 999         1      100.0      3.0         1
#
# [1000 rows x 16 columns]
